# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl

# Load the Excel file
workbook = openpyxl.load_workbook("EastWestAirlines.xlsx")

# Select the specific worksheet
worksheet = workbook.active

# Read the data from the worksheet
data = worksheet.values

# Convert the data into a DataFrame
columns = next(data)
airline_data = pd.DataFrame(data, columns=columns)

print(airline_data.head())
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
airline_data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline_data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
airline_data.shape
# Out:
# (3999, 12)

# %%
airline_data.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
airline_data.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
#airline_data = airline_data.drop(columns=['ID#'])

# %%
airline_data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(4, 3, figsize=(15,10))
sns.boxplot(airline_data.Balance, ax=ax[0,0])
sns.boxplot(airline_data.Qual_miles, ax=ax[0,1])
sns.boxplot(airline_data.cc1_miles, ax=ax[0,2])
sns.boxplot(airline_data.cc2_miles, ax=ax[1,0])
sns.boxplot(airline_data.cc3_miles, ax=ax[1,1])
sns.boxplot(airline_data.Bonus_miles, ax=ax[1,2])
sns.boxplot(airline_data.Bonus_trans, ax=ax[2,0])
sns.boxplot(airline_data.Flight_miles_12mo, ax=ax[2,1])
sns.boxplot(airline_data. Flight_trans_12, ax=ax[2,2])
sns.boxplot(airline_data.Days_since_enroll, ax=ax[3,0])
sns.boxplot(airline_data["Award?"] , ax=ax[3,1])
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(4, 3, figsize=(15,7))
sns.distplot(airline_data.Balance, ax=ax[0,0])
sns.distplot(airline_data.Qual_miles, ax=ax[0,1])
sns.distplot(airline_data.cc1_miles, ax=ax[0,2])
sns.distplot(airline_data.cc2_miles, ax=ax[1,0])
sns.distplot(airline_data.cc3_miles, ax=ax[1,1])
sns.distplot(airline_data.Bonus_miles, ax=ax[1,2])
sns.distplot(airline_data.Bonus_trans, ax=ax[2,0])
sns.distplot(airline_data.Flight_miles_12mo, ax=ax[2,1])
sns.distplot(airline_data. Flight_trans_12, ax=ax[2,2])
sns.distplot(airline_data.Days_since_enroll, ax=ax[3,0])
sns.distplot(airline_data["Award?"] , ax=ax[3,1])
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-12-152f99919508>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(airline_data.Balance, ax=ax[0,0])
# <ipython-input-12-152f99919508>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(airline_data.Qual_miles, ax=ax[0,1])
# ...

# %%
from sklearn.preprocessing import power_transform

Airlines2 = airline_data[["Balance","Qual_miles","cc1_miles","cc2_miles","cc3_miles","Bonus_miles","Bonus_trans","Flight_miles_12mo","Flight_trans_12","Days_since_enroll","Award?"]].values
Airlines2_transformed = power_transform(Airlines2, method='yeo-johnson')

# %%
Airlines2=pd.DataFrame(Airlines2_transformed,columns=["Balance","Qual_miles","cc1_miles","cc2_miles","cc3_miles","Bonus_miles","Bonus_trans","Flight_miles_12mo","Flight_trans_12","Days_since_enroll","Award?"])
Airlines2
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.346816   -0.244743  -0.844766        0.0        0.0    -1.178402
# 1    -0.633084   -0.244743  -0.844766        0.0        0.0    -1.132416
# 2    -0.038549   -0.244743  -0.844766        0.0        0.0    -0.191941
# 3    -0.821989   -0.244743  -0.844766        0.0        0.0    -0.924946
# 4     0.723596   -0.244743   1.343165        0.0        0.0     1.169363
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.662730   -0.244743  -0.844766        0.0        0.0     0.153811
# 3995  0.340486   -0.244743  -0.844766        0.0        0.0    -0.727886
# 3996  0.460388   -0.244743   1.058591        0.0        0.0     0.795077
# 3997  0.200904   -0.244743  -0.844766        0.0        0.0    -0.924946
# 3998 -1.803321   -0.244743  -0.844766        0.0        0.0    -1.826245
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
fig, ax = plt.subplots(4, 3, figsize=(15,7))
sns.distplot(Airlines2.Balance, ax=ax[0,0])
sns.distplot(Airlines2.Qual_miles, ax=ax[0,1])
sns.distplot(Airlines2.cc1_miles, ax=ax[0,2])
sns.distplot(Airlines2.cc2_miles, ax=ax[1,0])
sns.distplot(Airlines2.cc3_miles, ax=ax[1,1])
sns.distplot(Airlines2.Bonus_miles, ax=ax[1,2])
sns.distplot(Airlines2.Bonus_trans, ax=ax[2,0])
sns.distplot(Airlines2.Flight_miles_12mo, ax=ax[2,1])
sns.distplot(Airlines2.Flight_trans_12, ax=ax[2,2])
sns.distplot(Airlines2.Days_since_enroll, ax=ax[3,0])
sns.distplot(Airlines2["Award?"] , ax=ax[3,1])
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-915581c82a5a>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Airlines2.Balance, ax=ax[0,0])
# <ipython-input-15-915581c82a5a>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Airlines2.Qual_miles, ax=ax[0,1])
# ...

# %%
import scipy.cluster.hierarchy as sch

fig=plt.figure(figsize=(16,10))
dendrogram = sch.dendrogram(sch.linkage(Airlines2_transformed, method='average'))
plt.title("Dendogram",size=15)
# Out:
# Text(0.5, 1.0, 'Dendogram')

# %%
from sklearn.cluster import AgglomerativeClustering
hc1 = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'average')

# %%
y_hc1 = hc1.fit_predict(Airlines2_transformed)
Clusters=pd.DataFrame(y_hc1,columns=['Clusters'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
airline_data['cluster'] = y_hc1

# %%
airline_data.groupby('cluster').agg(['mean']).reset_index()
# Out:
#   cluster          ID#        Balance   Qual_miles cc1_miles cc2_miles  \
#                   mean           mean         mean      mean      mean
# 0       0  1799.350993  170339.198675  2508.019868  2.278146  1.013245
# 1       1  1891.090828  104075.087266     0.000000  2.290294  1.017809
# 2       2  1425.000000     125.000000     0.000000  1.000000  1.000000
# 3       3  2028.933333   57973.546667  2634.706667  2.000000  1.000000
# 4       4  2079.624622   55659.328172     0.000000  1.951662  1.013595
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.013245  28717.337748   18.344371       2574.390728        7.768212
# 1  1.016919  23897.578807   15.159394       1291.878896        3.845058
# 2  1.000000    125.000000    1.000000        125.000000        1.000000
# 3  1.000000  15002.626667   10.026667          0.000000        0.000000
# ...

# %%
for i in range(5):
    print("cluster", i)
    print("Total Members:", len(list(airline_data[airline_data['cluster'] == i]['ID#'].values)))
    print()
# Out:
# cluster 0
# Total Members: 151
#
# cluster 1
# Total Members: 1123
#
# cluster 2
# Total Members: 2
#
# cluster 3
# Total Members: 75
#
# cluster 4
# Total Members: 2648

# %%
fig=plt.figure(figsize=(16,10))
dendrogram = sch.dendrogram(sch.linkage(Airlines2_transformed, method='ward'))
plt.title("Dendogram",size=15)
# Out:
# Text(0.5, 1.0, 'Dendogram')

# %%
hc2 = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'ward')

# %%
y_hc2 = hc2.fit_predict(Airlines2_transformed)
Clusters=pd.DataFrame(y_hc2,columns=['Clusters'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
y_hc2 = hc2.fit_predict(Airlines2_transformed)
Clusters=pd.DataFrame(y_hc2,columns=['Clusters'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
airline_data['cluster'] = y_hc2

# %%
airline_data.groupby('cluster').agg(['mean']).reset_index()
# Out:
#   cluster          ID#        Balance   Qual_miles cc1_miles cc2_miles  \
#                   mean           mean         mean      mean      mean
# 0       0  2270.985322   33419.559030     0.000000  1.000000  1.022336
# 1       1  2113.270270   77788.952703     0.000000  1.000000  1.030405
# 2       2  1802.231267   87897.735430     0.000000  3.331175  1.000925
# 3       3  1875.539823  133049.712389  2550.061947  2.185841  1.008850
# 4       4  1642.568480  132880.887430     0.000000  3.718574  1.003752
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.005105   2837.693044    5.463944          0.000000        0.000000
# 1  1.000000   6038.932432    8.885135       1403.608108        4.155405
# 2  1.018501  29432.774283   15.990749          0.000000        0.000000
# 3  1.008850  24165.995575   15.584071       1720.057522        5.190265
# ...

# %%
for i in range(5):
    print("cluster", i)
    print("Total Members:", len(list(airline_data[airline_data['cluster'] == i]['ID#'].values)))
    print()
# Out:
# cluster 0
# Total Members: 1567
#
# cluster 1
# Total Members: 592
#
# cluster 2
# Total Members: 1081
#
# cluster 3
# Total Members: 226
#
# cluster 4
# Total Members: 533

# %%
fig=plt.figure(figsize=(16,10))
dendrogram = sch.dendrogram(sch.linkage(Airlines2_transformed, method='complete'))
plt.title("Dendogram",size=15)
# Out:
# Text(0.5, 1.0, 'Dendogram')

# %%
hc3 = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'complete')

# %%
y_hc3 = hc3.fit_predict(Airlines2_transformed)
Clusters=pd.DataFrame(y_hc3,columns=['Clusters'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
airline_data['cluster'] = y_hc3

# %%
airline_data.groupby('cluster').agg(['mean']).reset_index()
# Out:
#   cluster          ID#        Balance   Qual_miles cc1_miles cc2_miles  \
#                   mean           mean         mean      mean      mean
# 0       0  1475.911404  145838.029218     0.000000  3.541942  1.004713
# 1       1  2168.733392   39231.260927     0.000000  1.506119  1.016608
# 2       2  2607.044811   46620.754717     0.000000  1.268868  1.030660
# 3       3  2367.264151   46202.320755  2805.528302  1.000000  1.000000
# 4       4  1724.895954  159656.138728  2471.797688  2.549133  1.011561
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.032045  39928.083883   19.713478        809.139491        2.377003
# 1  1.005682   7506.878497    7.910839         53.164773        0.161713
# 2  1.000000   8399.268868    9.099057       1110.594340        3.367925
# 3  1.000000   2909.528302    3.962264        188.245283        0.566038
# ...

# %%
for i in range(5):
    print("cluster", i)
    print("Total Members:", len(list(airline_data[airline_data['cluster'] == i]['ID#'].values)))
    print()
# Out:
# cluster 0
# Total Members: 1061
#
# cluster 1
# Total Members: 2288
#
# cluster 2
# Total Members: 424
#
# cluster 3
# Total Members: 53
#
# cluster 4
# Total Members: 173

# %%
fig=plt.figure(figsize=(16,10))
dendrogram = sch.dendrogram(sch.linkage(Airlines2_transformed, method='single'))
plt.title("Dendogram",size=15)
# Out:
# Text(0.5, 1.0, 'Dendogram')

# %%
hc4 = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'single')
y_hc4 = hc4.fit_predict(Airlines2_transformed)
Clusters=pd.DataFrame(y_hc4,columns=['Clusters'])
airline_data['cluster'] = y_hc4
airline_data.groupby('cluster').agg(['mean']).reset_index()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
#   cluster          ID#        Balance   Qual_miles cc1_miles cc2_miles  \
#                   mean           mean         mean      mean      mean
# 0       0  2028.933333   57973.546667  2634.706667  2.000000  1.000000
# 1       1  1799.350993  170339.198675  2508.019868  2.278146  1.013245
# 2       2  3018.000000       0.000000     0.000000  1.000000  1.000000
# 3       3  2079.624622   55659.328172     0.000000  1.951662  1.013595
# 4       4  1889.258897  103982.716192     0.000000  2.289146  1.017794
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.000000  15002.626667   10.026667          0.000000        0.000000
# ...

# %%
for i in range(5):
    print("cluster", i)
    print("Total Members:", len(list(airline_data[airline_data['cluster'] == i]['ID#'].values)))
    print()
# Out:
# cluster 0
# Total Members: 75
#
# cluster 1
# Total Members: 151
#
# cluster 2
# Total Members: 1
#
# cluster 3
# Total Members: 2648
#
# cluster 4
# Total Members: 1124

# %% [markdown]
# # **K Means** **Clustering**

# %%
from sklearn.cluster import KMeans

from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(Airlines2_transformed)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
clusters_new = KMeans(5, random_state=42)
clusters_new.fit(Airlines2_transformed)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
KM_label=clusters_new.labels_
airline_data['cluster'] = clusters_new.labels_
clusters_new.cluster_centers_
# Out:
# array([[-6.75212840e-01, -2.32991180e-01, -8.35590446e-01,
#          4.66045113e-19,  7.89631277e-33, -9.09080934e-01,
#         -8.19433548e-01, -6.82084186e-01, -6.73778986e-01,
#         -3.10971055e-01, -5.14035484e-01],
#        [ 3.71613101e-01, -2.44743303e-01,  9.10506666e-01,
#          2.91327607e-19,  2.55720899e-18,  7.17781846e-01,
#          5.92471428e-01, -6.83308041e-01, -6.74970335e-01,
#          2.39016631e-01,  1.81555873e-01],
#        [ 1.60074522e-02, -2.44743303e-01, -8.19239258e-01,
#          7.32640630e-19, -4.23704588e-33, -2.79105284e-01,
#         -2.72262658e-01,  1.45172819e+00,  1.43587521e+00,
#         -9.52588092e-02,  7.15349601e-02],
#        [ 7.54505594e-01, -2.44743303e-01,  1.11374957e+00,
#          2.77052025e-19,  2.98460591e-18,  1.03665259e+00,
#          1.04603128e+00,  1.45646102e+00,  1.41053352e+00,
#          3.58290326e-01,  6.72519442e-01],
#        [ 5.95617244e-01,  4.08591363e+00,  6.27073775e-02,
# ...

# %%
A=airline_data .iloc[:,1:].groupby('cluster').agg(['mean']).reset_index()

# %%
for i in range(5):
    print("cluster", i)
    print("Total Members:", len(list(airline_data[airline_data['cluster'] == i]['ID#'].values)))
    print()
# Out:
# cluster 0
# Total Members: 1474
#
# cluster 1
# Total Members: 1179
#
# cluster 2
# Total Members: 573
#
# cluster 3
# Total Members: 551
#
# cluster 4
# Total Members: 222

# %% [markdown]
# # **DBSCAN**

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.8, min_samples=6)
dbscan.fit(Airlines2)
# Out:
# DBSCAN(eps=0.8, min_samples=6)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 4, 6, 0])

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])

# %%
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 3994        3
# 3995        5
# 3996        4
# 3997        6
# 3998        0
#
# [3999 rows x 1 columns]

# %%
Airlines3 = pd.concat([airline_data,cl],axis=1)

# %%
Airlines3
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
print(metrics.silhouette_score(Airlines2_transformed,y_hc1))
# Out:
# 0.24511194875209383

# %%
print(metrics.silhouette_score(Airlines2_transformed,y_hc2))
# Out:
# 0.3240550069814065

# %%
print(metrics.silhouette_score(Airlines2_transformed,y_hc3))
# Out:
# 0.19985213995606269

# %%
print(metrics.silhouette_score(Airlines2_transformed,y_hc4))
# Out:
# 0.2971406781364072

# %%
print(metrics.silhouette_score(Airlines2_transformed,clusters_new.labels_))
# Out:
# 0.32518610185189556
